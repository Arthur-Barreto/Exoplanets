# %%
from lightkurve import search_targetpixelfile
import numpy as np
pixelFile = search_targetpixelfile('KIC 6922244', quarter=4).download()
# pegar a curva de luz da estrela, não do planeta
# Out:
# C:\Users\arthu\anaconda3\lib\site-packages\lightkurve\search.py:346: LightkurveWarning: Warning: 4 files available to download. Only the first file has been downloaded. Please use `download_all()` or specify additional criteria (e.g. quarter, campaign, or sector) to limit your search.
#   warnings.warn(

# %%
pixelFile
# Out:
# KeplerTargetPixelFile Object (ID: 6922244)

# %%
lc = pixelFile.to_lightcurve(aperture_mask=pixelFile.pipeline_mask)

# %%
lc.meta['MISSION']
# Out:
# 'Kepler'

# %%
lc.meta['QUARTER']
# Out:
# 4

# %%
lc.time
# Out:
# <Time object: scale='tdb' format='bkjd' value=[352.36644886 352.36712985 352.36781104 ... 383.42321606 383.42389716
#  383.42457836]>

# %%
lc.plot();

# %%
flat_lc = lc.flatten(window_length=401)
flat_lc.plot();

# %%
folded_lc = flat_lc.fold(period=3.522)
folded_lc.plot();

# %%
# rodando para todos os valores possiveis, com delta de 1d
lis_tempo = np.linspace(3.5,3.6,100)
for dt in lis_tempo:
    # 400d é o tmax da kepler
    folded_lc = flat_lc.fold(period=dt)
    pg = lc.to_periodogram(oversample_factor=1)
    pg.plot(title=f'T = {dt} dias')
# Out:
# C:\Users\arthu\anaconda3\lib\site-packages\lightkurve\periodogram.py:364: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()

# %%
binned_lc = folded_lc.bin(binsize=10)
binned_lc.plot();
# Out:
# <ipython-input-30-1c8c31ee9084>:1: LightkurveDeprecationWarning: "binsize" was deprecated in version 2.0 and will be removed in a future version.
#         Use time_bin_size instead.
#   binned_lc = folded_lc.bin(binsize=10)

# %%
lc.remove_nans().flatten(window_length=401).fold(period=3.5225).bin(binsize=10).plot();
# Out:
# <ipython-input-31-bfa113d363b9>:1: LightkurveDeprecationWarning: "binsize" was deprecated in version 2.0 and will be removed in a future version.
#         Use time_bin_size instead.
#   lc.remove_nans().flatten(window_length=401).fold(period=3.5225).bin(binsize=10).plot();

# %%
import numpy as np
periodogram = flat_lc.to_periodogram(method="bls", period=np.arange(0.3, 10, 0.001))
periodogram.plot();
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-7af249baeaf9> in <module>
#       1 import numpy as np
# ----> 2 periodogram = flat_lc.to_periodogram(method="bls", period=np.arange(0.3, 10, 0.001))
#       3 periodogram.plot();
#
# ~\anaconda3\lib\site-packages\lightkurve\lightcurve.py in to_periodogram(self, method, **kwargs)
#    2183             from .periodogram import BoxLeastSquaresPeriodogram
#    2184
# -> 2185             return BoxLeastSquaresPeriodogram.from_lightcurve(lc=self, **kwargs)
#    2186         else:
#    2187             from .periodogram import LombScarglePeriodogram
#
# ~\anaconda3\lib\site-packages\lightkurve\periodogram.py in from_lightcurve(lc, **kwargs)
#    1159                 frequency_factor=frequency_factor,
#    1160             )
# -> 1161         result = bls.power(period, duration, **kwargs)
# ...

# %%
best_fit_period = periodogram.period_at_max_power
print('Best fit period: {:.5f}'.format(best_fit_period))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-efb01135950c> in <module>
# ----> 1 best_fit_period = periodogram.period_at_max_power
#       2 print('Best fit period: {:.5f}'.format(best_fit_period))
#
# NameError: name 'periodogram' is not defined

# %% [markdown]
# O periodo máximo é de 29.942265 d

# %%
lc.fold(period=pg.period_at_max_power).scatter();

# %%
lc.fold(period=4*pg.period_at_max_power, wrap_phase=0.2).scatter();

# %%
import astropy.units as u
pg = lc.to_periodogram(minimum_period=0.9*u.day, maximum_period=1.2*u.day, oversample_factor=10)
pg.period_at_max_power
# Out:
# <Quantity 1.16725387 d>

# %%
lc.fold(period=pg.period_at_max_power, wrap_phase=0.8).scatter();
